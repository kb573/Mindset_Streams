# %%
from Mindset_Streams.file_import import file_to_df, attach_sentiment
from Mindset_Streams.mindset_streams import edge_valence, stream_graph

# %%
#import json data as a Pandas Dataframe
df = file_to_df('demo_data.json')
df
# Out:
#           word 1      word 2
# 0    application        work
# 1         laptop        work
# 2     university        work
# 3         laptop    computer
# 4         degree  university
# ..           ...         ...
# 165        point        line
# 166    curricula     program
# 167         draw        line
# 168         line    straight
# 169         draw       paint
#
# [170 rows x 2 columns]

# %%
#import sentiment data and attach to dataframe
df = attach_sentiment(df, 'valence_data.json')
df
# Out:
#           word 1      word 2 word 1 valence word 2 valence
# 0    application        work       negative        neutral
# 1         laptop        work        neutral        neutral
# 2     university        work       positive        neutral
# 3         laptop    computer        neutral       positive
# 4         degree  university        neutral       positive
# ..           ...         ...            ...            ...
# 165        point        line       negative        neutral
# 166    curricula     program        neutral        neutral
# 167         draw        line        neutral        neutral
# 168         line    straight        neutral        neutral
# 169         draw       paint        neutral        neutral
#
# [170 rows x 4 columns]

# %%
#generate edge valence lables
df = edge_valence(df)
df
# Out:
#           word 1      word 2 word 1 valence word 2 valence edge valence
# 0    application        work       negative        neutral      neutral
# 1         laptop        work        neutral        neutral      neutral
# 2     university        work       positive        neutral      neutral
# 3         laptop    computer        neutral       positive      neutral
# 4         degree  university        neutral       positive      neutral
# ..           ...         ...            ...            ...          ...
# 165        point        line       negative        neutral      neutral
# 166    curricula     program        neutral        neutral      neutral
# 167         draw        line        neutral        neutral      neutral
# 168         line    straight        neutral        neutral      neutral
# 169         draw       paint        neutral        neutral      neutral
#
# [170 rows x 5 columns]

# %%
#generate mindset stream graph visualisation and statistics
stream_graph, stats = stream_graph(df, 'work', 'physics')

# %%
stats
# Out:
#                                    Path Structure   Path Type  \
# 0    [work, university, research, model, physics]  mixed path
# 1  [work, university, research, science, physics]  mixed path
#
#    Sum of Edge Betweenness Centralities
# 0                                0.4527
# 1                                0.7769
